# %%
uploaded = files.upload()

for fn in uploaded.keys():
  df = pd.read_csv(fn)
  print(df.head())
#File wasnt uploading the normal way so I used code from ChatGPT
# Out:
#      <input type="file" id="files-48ffc8e6-f0ff-417a-84e2-32d7fa01d313" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48ffc8e6-f0ff-417a-84e2-32d7fa01d313">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from plotnine import ggplot, aes, geom_point, scale_x_log10

(
    ggplot(df, aes(
        x="income",
        y="life_exp",
        size="population",
        color="six_regions"
    ))
    + geom_point()
    + scale_x_log10()
)
# Out:
# /usr/local/lib/python3.12/dist-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 4 rows containing missing values.

# %%
from plotnine import geom_line

(ggplot(df,
aes(
  x = "income",
  y = "life_exp",
  color = "income"
))
+ geom_point()
+ geom_line()
)
# Out:
# /usr/local/lib/python3.12/dist-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 2 rows containing missing values.
# /usr/local/lib/python3.12/dist-packages/plotnine/geoms/geom_path.py:100: PlotnineWarning: geom_path: Removed 2 rows containing missing values.

# %% [markdown]
# This graph is much harder to read as compared to the scatter plot. It also doesnt show the density of each point based on population

# %%
uploaded = files.upload()

for fn in uploaded.keys():
  df1 = pd.read_csv(fn)
  print(df.head())
# Out:
#      <input type="file" id="files-c22572af-aa9d-4e12-96b9-88a37d0b73e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c22572af-aa9d-4e12-96b9-88a37d0b73e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
(
    ggplot(df1, aes(
        x="imports",
        y="exports",
        color="six_regions",
        size='exports'
    ))
    + geom_point()
    + scale_x_log10()
)
# Out:
# /usr/local/lib/python3.12/dist-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 35 rows containing missing values.

# %%
from plotnine import geom_density
(ggplot(df1,
aes(
  x = "exports",
  fill = "eight_regions"
))
+ geom_density(alpha = 0.5)
)
# Out:
# /usr/local/lib/python3.12/dist-packages/plotnine/layer.py:284: PlotnineWarning: stat_density : Removed 35 rows containing non-finite values.

# %% [markdown]
# This graph is not good because it only shows exports and it doesnt really explain how the height of the graph is associated with the exports.

# %%
uploaded = files.upload()

for fn in uploaded.keys():
  df2 = pd.read_csv(fn)
  print(df.head())
# Out:
#      <input type="file" id="files-e6bf6a30-c851-405d-a26e-28d5f03b235b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e6bf6a30-c851-405d-a26e-28d5f03b235b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
(
    ggplot(df2, aes(
        x="gdp",
        y="internet_users",
        color="four_regions"
    ))
    + geom_point()
    #+ scale_x_log10()
)
# Out:
# /usr/local/lib/python3.12/dist-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 25 rows containing missing values.

# %%
from plotnine import theme_classic
(ggplot(df2, aes(x = "internet_users", y = "gdp", fill = "internet_users"))
+ geom_boxplot()
+ theme_classic()
)
# Out:
# /usr/local/lib/python3.12/dist-packages/plotnine/layer.py:284: PlotnineWarning: stat_boxplot : Removed 25 rows containing non-finite values.

# %% [markdown]
# This one is bad because it doesnt give any real information. The graph is too compressed and the data is too close together you cant tell what youre looking at.
